# %% [markdown]
# ##  Mini Project for Data Science

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in '%s': %s" % (cwd, files))
# Out:
# Files in '/content': ['.config', 'drive', 'sample_data']

# %%
import pandas as pd
import numpy
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# %% [markdown]
# ### Cooking Data Visualization

# %%
test_data = pd.read_json("drive/My Drive/data/test.json")
#read Cooking test data by utf-8
test_data.head()
# Out:
#       id                                        ingredients
# 0  18009  [baking powder, eggs, all-purpose flour, raisi...
# 1  28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2  41580  [sausage links, fennel bulb, fronds, olive oil...
# 3  29752  [meat cuts, file powder, smoked sausage, okra,...
# 4  35687  [ground black pepper, salt, sausage casings, l...

# %%
train_data = pd.read_json("drive/My Drive/data/train.json")
#read Cooking train data by utf-8
train_data.head()
# Out:
#        cuisine     id                                        ingredients
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
train_data.shape()

# %%
#This is for knowing number of train_data and test_data
print("Train Data shape: " + str(train_data.shape))
print("Test Data shape: " + str(test_data.shape))
# Out:
# Train Data shape: (39774, 3)
# Test Data shape: (9944, 2)

# %%
train_id = pd.DataFrame(train_data['id'])
train_id.head()
# Out:
#       id
# 0  10259
# 1  25693
# 2  20130
# 3  22213
# 4  13162

# %%
train_cuisine = pd.DataFrame(train_data["cuisine"])
train_cuisine.head()
# Out:
#        cuisine
# 0        greek
# 1  southern_us
# 2     filipino
# 3       indian
# 4       indian

# %%
train_ingredients = pd.DataFrame(train_data["ingredients"])
train_ingredients.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6013a8f8df6e> in <module>()
# ----> 1 train_ingredients = pd.DataFrame(train_data["ingredients"])
#       2 train_ingredients.info
#
# NameError: name 'pd' is not defined

# %%
test_id = pd.DataFrame(test_data["id"])
test_id.head()
# Out:
#       id
# 0  18009
# 1  28583
# 2  41580
# 3  29752
# 4  35687

# %%
test_ingred = pd.DataFrame(test_data["ingredients"])
test_ingred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9944 entries, 0 to 9943
# Data columns (total 1 columns):
# ingredients    9944 non-null object
# dtypes: object(1)
# memory usage: 77.8+ KB

# %%
yummly_data = pd.read_html("https://www.yummly.com/recipe/Summer-Corn-Salad-9015363")
print("Data type : ", type(yummly_data))
print("Data tables : ", len(yummly_data))
# Out:
# Data type :  <class 'list'>
# Data tables :  2

# %%
#Nutrition data ~protein
yummly_data[0].head()
# Out:
#                                  0
# 0  Calories300Calories from Fat250
# 1                    % DAILY VALUE
# 2                  Total Fat28g43%
# 3               Saturated Fat4g20%
# 4                        Trans Fat

# %%
for i in range(5):
  print("Summer Corn Salad: " + yummly_data[0][0][i])
# Out:
# Summer Corn Salad: Calories300Calories from Fat250
# Summer Corn Salad: % DAILY VALUE
# Summer Corn Salad: Total Fat28g43%
# Summer Corn Salad: Saturated Fat4g20%
# Summer Corn Salad: Trans Fat

# %%
#Nutrition data ~Iron
yummly_data[1].head()
# Out:
#                          0
# 0     Calories from Fat250
# 1            % DAILY VALUE
# 2  Total Carbohydrate13g4%
# 3       Dietary Fiber6g24%
# 4               Sugars3g6%

# %%
yummly_data[1].iloc[[0,4]]
# Out:
#                       0
# 0  Calories from Fat250
# 4            Sugars3g6%

# %%
train_data['id'] = train_data['id'].astype('category')
train_data['cuisine'] = train_data['cuisine'].astype('category')
train_data['ingredients'] = train_data['ingredients'].astype('category')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39774 entries, 0 to 39773
# Data columns (total 3 columns):
# cuisine        39774 non-null category
# id             39774 non-null category
# ingredients    39774 non-null category
# dtypes: category(3)
# memory usage: 1.8 MB
